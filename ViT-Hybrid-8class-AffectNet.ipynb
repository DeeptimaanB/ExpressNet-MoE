# %%
import os
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
import mediapipe as mp
import seaborn as sns
import matplotlib.pyplot as plt
import threading

from tensorflow import keras
from tensorflow.keras import layers, backend as K
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input, Concatenate
)
from tensorflow.keras.utils import get_custom_objects, to_categorical
from tensorflow.keras.applications import ResNet50  # Using ResNet50 as an example for ViT alternative
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

from keras_vggface.vggface import VGGFace  # Import VGGFace2 Model
from keras_vggface.utils import preprocess_input

# Suppress TensorFlow logs (only show errors)
tf.get_logger().setLevel('ERROR')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # Suppresses INFO (1), WARNING (2), and ERROR (3)
# Out:
# 2025-03-03 15:45:57.705245: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-03 15:45:58.248101: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load the dataset
labels_df = pd.read_csv('AffectNet/labels.csv')

# Stratified train-test split to maintain class balance
train_df, val_df = train_test_split(labels_df, test_size=0.2, random_state=42, stratify=labels_df['label'])

print("Training Dataset : " + str(train_df['label'].value_counts()))
print("Validation Dataset : " + str(val_df['label'].value_counts()))

# Initialize face detection model
mp_face_detection = mp.solutions.face_detection
face_detector = mp_face_detection.FaceDetection(model_selection=1, min_detection_confidence=0.5)

# Set the target image size (IMG_SIZE)
IMG_SIZE = 96
# Out:
# Training Dataset : label
# surprise    3693
# happy       3469
# anger       2886
# disgust     2778
# contempt    2595
# fear        2434
# sad         2396
# neutral     2289
# Name: count, dtype: int64
# Validation Dataset : label
# surprise    923
# happy       867
# anger       722
# disgust     694
# contempt    649
# fear        609
# sad         599
# neutral     572
# Name: count, dtype: int64
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741016760.045970 2702547 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1741016760.165472 2702641 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 535.183.06), renderer: NVIDIA TITAN Xp/PCIe/SSE2

# %%
lock = threading.Lock()
def detect_and_crop_face(image):
    """Detects and crops the face using BlazeFace (MediaPipe), then resizes to target size."""
    with lock:
        if image is None:
            print("Empty")
            
        img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        # Process the image with face detection
        results = face_detector.process(img_rgb)
    
        if results.detections:
            for detection in results.detections:
                bboxC = detection.location_data.relative_bounding_box
                h, w, _ = image.shape
    
                # Calculate bounding box coordinates
                x_min = int(bboxC.xmin * w)
                y_min = int(bboxC.ymin * h)
                box_width = int(bboxC.width * w)
                box_height = int(bboxC.height * h)
    
                # Optionally expand the bounding box slightly
                x_min = max(0, x_min - box_width // 10)
                y_min = max(0, y_min - box_height // 10)
                box_width = min(w, box_width + box_width // 5)
                box_height = min(h, box_height + box_height // 5)
    
                # Crop the face from the image using the bounding box
                cropped_face = image[y_min:y_min + box_height, x_min:x_min + box_width]
                
                # Resize the cropped face to the target size (IMG_SIZE x IMG_SIZE)
                return cv2.resize(cropped_face, (IMG_SIZE, IMG_SIZE))
    
        # If no face detected, return resized version of the original image
        return cv2.resize(image, (IMG_SIZE, IMG_SIZE))

# %%
# Define emotion labels
emotion_labels = ['anger', 'contempt', 'disgust', 'sad', 'happy', 'fear', 'neutral', 'surprise']
num_classes = len(emotion_labels)  # 8 classes

def image_generator(dataframe, batch_size=32):
    while True:
        batch_images = []
        batch_labels = []
        
        dataframe = dataframe.sample(frac=1).reset_index(drop=True)  # Shuffle at start of epoch

        for i in range(len(dataframe)):
            row = dataframe.iloc[i]
            img_path = os.path.join('AffectNet', row['pth'])  # Ensure path correctness
            image = cv2.imread(img_path)

            # Detect and crop the face
            face = detect_and_crop_face(image)
            if face is not None:
                batch_images.append(face)

                # Convert label from string to index
                label_str = row['label']
                if label_str not in emotion_labels:
                    print(f"Warning: Unexpected label '{label_str}' found!")
                    continue  # Skip if label is not in predefined list

                label_index = emotion_labels.index(label_str)  # Convert "happy" -> 4

                # Fix: Ensure correct shape for one-hot encoding
                one_hot_label = to_categorical(label_index, num_classes=num_classes)

                batch_labels.append(one_hot_label)

            # Yield batch when full
            if len(batch_images) == batch_size:
                yield np.array(batch_images).astype('float32') / 255.0, np.array(batch_labels)
                batch_images = []
                batch_labels = []

        # Yield remaining images if any
        if len(batch_images) > 0:
            yield np.array(batch_images).astype('float32') / 255.0, np.array(batch_labels)
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1741016760.225789 2702636 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
x_batch, y_batch = next(image_generator(train_df, batch_size=32))
print("Batch X shape:", x_batch.shape)  # Expected: (batch_size, 96, 96, 3)
print("Batch Y shape:", y_batch.shape)  # Expected: (batch_size, 8) for one-hot labels
# Out:
# Batch X shape: (32, 96, 96, 3)
# Batch Y shape: (32, 8)

# %%
# Identity Normalization (Idn) Module with Batch Normalization
def create_identity_normalization():
    inputs = keras.Input(shape=(96, 96, 3))
    x = layers.Conv2D(32, (3, 3), activation="relu", padding="same")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(64, (3, 3), activation="relu", padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation="relu")(x)
    x = layers.BatchNormalization()(x)
    return keras.Model(inputs, x, name="IdentityNormalization")

# Mixture of Experts (MoE) Module with Improved Gating
def create_moe(input_dim, num_experts=4, top_k=2, name="MoE"):
    inputs = keras.Input(shape=(input_dim,))
    experts = [layers.Dense(input_dim, activation="relu") for _ in range(num_experts)]
    
    gating_logits = layers.Dense(num_experts)(inputs)
    gating = layers.Softmax()(gating_logits)
    
    expert_outputs = tf.stack([experts[i](inputs) for i in range(num_experts)], axis=1)
    top_k_values, top_k_indices = tf.math.top_k(gating, k=top_k)

    output = tf.zeros_like(inputs)
    for i in range(top_k):
        expert_idx = top_k_indices[:, i]
        expert_out = tf.gather(expert_outputs, expert_idx, axis=1, batch_dims=1)
        output += tf.expand_dims(top_k_values[:, i], -1) * expert_out
    
    return keras.Model(inputs, output, name=name)

# CNN Feature Extractor with Dropout
def create_cnn_feature_extractor():
    inputs = keras.Input(shape=(96, 96, 3))
    x = layers.Conv2D(32, (3, 3), activation="relu", padding="same")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(64, (3, 3), activation="relu", padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(128, (3, 3), activation="relu", padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.3)(x)
    return keras.Model(inputs, x, name="CNNFeatureExtractor")

# Transformer Feature Extractor using ResNet50
def create_transformer_feature_extractor():
    inputs = keras.Input(shape=(96, 96, 3))
    base_model = ResNet50(input_shape=(96, 96, 3), include_top=False, weights="imagenet")(inputs)
    x = layers.GlobalAveragePooling2D()(base_model)
    x = layers.Dense(512, activation="relu")(x)
    x = layers.Dropout(0.3)(x)
    return keras.Model(inputs, x, name="TransformerFeatureExtractor")

# Complete FER Model
def create_fer_model(num_classes=8):
    inputs = keras.Input(shape=(96, 96, 3))
    
    idn_model = create_identity_normalization()
    cnn_model = create_cnn_feature_extractor()
    transformer_model = create_transformer_feature_extractor()
    
    identity_features = idn_model(inputs)
    cnn_features = cnn_model(inputs)
    transformer_features = transformer_model(inputs)
    
    combined_features = layers.Concatenate()([cnn_features, transformer_features])
    dense_layer = layers.Dense(2048, activation="relu")(combined_features)
    dense_layer = layers.Dropout(0.3)(dense_layer)  # Prevent Overfitting
    
    idn_moe = create_moe(128, name="MoE_Identity")(identity_features)
    expression_moe = create_moe(2048, name="MoE_Expression")(dense_layer)
    
    final_features = layers.Concatenate()([idn_moe, expression_moe])
    output = layers.Dense(num_classes, activation="softmax")(final_features)
    
    return keras.Model(inputs, output, name="FER_IdentityAware_MoE")

# Compile and Initialize Model
num_classes = 8
model = create_fer_model(num_classes)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4), 
              loss="categorical_crossentropy", 
              metrics=["accuracy"])

# Update model checkpoint to save the best model based on validation accuracy
checkpoint = ModelCheckpoint('AffectNet-Ensemble-Vision-v3.h5', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

model.summary()
# Out:
# 2025-03-03 15:46:01.122991: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2698 MB memory:  -> device: 0, name: NVIDIA TITAN Xp, pci bus id: 0000:19:00.0, compute capability: 6.1
# 2025-03-03 15:46:01.123693: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 862 MB memory:  -> device: 1, name: NVIDIA TITAN Xp, pci bus id: 0000:1a:00.0, compute capability: 6.1
# 2025-03-03 15:46:01.124216: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 10081 MB memory:  -> device: 2, name: NVIDIA TITAN Xp, pci bus id: 0000:67:00.0, compute capability: 6.1
# 2025-03-03 15:46:01.124703: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 9493 MB memory:  -> device: 3, name: NVIDIA TITAN Xp, pci bus id: 0000:68:00.0, compute capability: 6.1
# Model: "FER_IdentityAware_MoE"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 96, 96, 3)]  0           []
#
#  CNNFeatureExtractor (Functiona  (None, 256)         127168      ['input_1[0][0]']
#  l)
#
#  TransformerFeatureExtractor (F  (None, 512)         24636800    ['input_1[0][0]']
#  unctional)
#
#  concatenate (Concatenate)      (None, 768)          0           ['CNNFeatureExtractor[0][0]',
#                                                                   'TransformerFeatureExtractor[0][
#                                                                  0]']
#
#  dense_3 (Dense)                (None, 2048)         1574912     ['concatenate[0][0]']
#
#  IdentityNormalization (Functio  (None, 128)         28608       ['input_1[0][0]']
#  nal)
#
#  dropout_2 (Dropout)            (None, 2048)         0           ['dense_3[0][0]']
#
#  MoE_Identity (Functional)      (None, 128)          66564       ['IdentityNormalization[0][0]']
#
#  MoE_Expression (Functional)    (None, 2048)         16793604    ['dropout_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 2176)         0           ['MoE_Identity[0][0]',
#                                                                   'MoE_Expression[0][0]']
#
#  dense_14 (Dense)               (None, 8)            17416       ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 43,245,072
# Trainable params: 43,191,056
# Non-trainable params: 54,016
# __________________________________________________________________________________________________

# %%
history = model.fit(
    image_generator(train_df, batch_size=32),
    steps_per_epoch=len(train_df) // 32,  # Ensure correct number of steps
    epochs=50,
    validation_data=image_generator(val_df, batch_size=32),
    validation_steps=len(val_df) // 32,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/50
# 2025-03-03 15:46:03.817225: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2025-03-03 15:46:15.248081: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2025-03-03 15:46:15.816812: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0xaf99c40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-03-03 15:46:15.816865: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA TITAN Xp, Compute Capability 6.1
# 2025-03-03 15:46:15.816880: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (1): NVIDIA TITAN Xp, Compute Capability 6.1
# 2025-03-03 15:46:15.816893: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (2): NVIDIA TITAN Xp, Compute Capability 6.1
# 2025-03-03 15:46:15.816905: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (3): NVIDIA TITAN Xp, Compute Capability 6.1
# 2025-03-03 15:46:15.826781: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-03-03 15:46:15.854434: W tensorflow/compiler/xla/service/gpu/llvm_gpu_backend/gpu_backend_lib.cc:530] Can't find libdevice directory ${CUDA_DIR}/nvvm/libdevice. This may result in compilation or runtime failures, if the program we try to run uses routines from libdevice.
# Searched for CUDA in the following directories:
#   ./cuda_sdk_lib
#   /usr/local/cuda-11.8
#   /usr/local/cuda
#   .
# You can choose the search directory by setting xla_gpu_cuda_data_dir in HloModule's DebugOptions.  For most apps, setting the environment variable XLA_FLAGS=--xla_gpu_cuda_data_dir=/path/to/cuda will work.
# 2025-03-03 15:46:15.972355: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-03-03 15:46:17.868299: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-03 15:46:17.902222: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.41GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-03 15:46:19.063009: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.30GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-03 15:46:19.211300: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-03 15:46:21.334126: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 704/704 [==============================] - ETA: 0s - loss: 1.4170 - accuracy: 0.4746
# 2025-03-03 15:51:16.970252: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_accuracy improved from -inf to 0.25923, saving model to AffectNet-Ensemble-Vision-v3.h5
# 704/704 [==============================] - 384s 502ms/step - loss: 1.4170 - accuracy: 0.4746 - val_loss: 1.9725 - val_accuracy: 0.2592
# Epoch 2/50
# 2025-03-03 15:52:28.668171: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-03 15:52:28.682526: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-03 15:52:28.741334: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-03 15:52:28.750094: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-03 15:52:28.795182: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.55GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 704/704 [==============================] - ETA: 0s - loss: 0.8983 - accuracy: 0.6792
# Epoch 2: val_accuracy improved from 0.25923 to 0.63778, saving model to AffectNet-Ensemble-Vision-v3.h5
# 704/704 [==============================] - 356s 505ms/step - loss: 0.8983 - accuracy: 0.6792 - val_loss: 1.0398 - val_accuracy: 0.6378
# Epoch 3/50
# 704/704 [==============================] - ETA: 0s - loss: 0.5996 - accuracy: 0.7876
# Epoch 3: val_accuracy did not improve from 0.63778
# 704/704 [==============================] - 351s 500ms/step - loss: 0.5996 - accuracy: 0.7876 - val_loss: 1.1260 - val_accuracy: 0.6342
# Epoch 4/50
# 704/704 [==============================] - ETA: 0s - loss: 0.3701 - accuracy: 0.8729
# Epoch 4: val_accuracy did not improve from 0.63778
# 704/704 [==============================] - 352s 500ms/step - loss: 0.3701 - accuracy: 0.8729 - val_loss: 1.2474 - val_accuracy: 0.6275
# Epoch 5/50
# 704/704 [==============================] - ETA: 0s - loss: 0.2519 - accuracy: 0.9140
# Epoch 5: val_accuracy improved from 0.63778 to 0.64737, saving model to AffectNet-Ensemble-Vision-v3.h5
# 704/704 [==============================] - 351s 500ms/step - loss: 0.2519 - accuracy: 0.9140 - val_loss: 1.2734 - val_accuracy: 0.6474
# Epoch 6/50
# 704/704 [==============================] - ETA: 0s - loss: 0.1724 - accuracy: 0.9420
# Epoch 6: val_accuracy improved from 0.64737 to 0.66264, saving model to AffectNet-Ensemble-Vision-v3.h5
# 704/704 [==============================] - 352s 501ms/step - loss: 0.1724 - accuracy: 0.9420 - val_loss: 1.3925 - val_accuracy: 0.6626
# Epoch 7/50
# 704/704 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.9521
# Epoch 7: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 499ms/step - loss: 0.1434 - accuracy: 0.9521 - val_loss: 1.5138 - val_accuracy: 0.6461
# Epoch 8/50
# 704/704 [==============================] - ETA: 0s - loss: 0.1327 - accuracy: 0.9556
# Epoch 8: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 500ms/step - loss: 0.1327 - accuracy: 0.9556 - val_loss: 1.5983 - val_accuracy: 0.6481
# Epoch 9/50
# 704/704 [==============================] - ETA: 0s - loss: 0.1123 - accuracy: 0.9618
# Epoch 9: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 499ms/step - loss: 0.1123 - accuracy: 0.9618 - val_loss: 1.4363 - val_accuracy: 0.6495
# Epoch 10/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0971 - accuracy: 0.9677
# Epoch 10: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 500ms/step - loss: 0.0971 - accuracy: 0.9677 - val_loss: 1.6913 - val_accuracy: 0.6475
# Epoch 11/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0945 - accuracy: 0.9701
# Epoch 11: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 500ms/step - loss: 0.0945 - accuracy: 0.9701 - val_loss: 1.7177 - val_accuracy: 0.6467
# Epoch 12/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0951 - accuracy: 0.9694
# Epoch 12: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 500ms/step - loss: 0.0951 - accuracy: 0.9694 - val_loss: 1.6290 - val_accuracy: 0.6465
# Epoch 13/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0807 - accuracy: 0.9736
# Epoch 13: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 501ms/step - loss: 0.0807 - accuracy: 0.9736 - val_loss: 1.8576 - val_accuracy: 0.6467
# Epoch 14/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9756
# Epoch 14: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 500ms/step - loss: 0.0758 - accuracy: 0.9756 - val_loss: 1.6750 - val_accuracy: 0.6369
# Epoch 15/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0705 - accuracy: 0.9779
# Epoch 15: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 500ms/step - loss: 0.0705 - accuracy: 0.9779 - val_loss: 1.8344 - val_accuracy: 0.6436
# Epoch 16/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9772
# Epoch 16: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 499ms/step - loss: 0.0688 - accuracy: 0.9772 - val_loss: 1.7629 - val_accuracy: 0.6374
# Epoch 17/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0701 - accuracy: 0.9767
# Epoch 17: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 350s 498ms/step - loss: 0.0701 - accuracy: 0.9767 - val_loss: 1.9051 - val_accuracy: 0.6436
# Epoch 18/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0647 - accuracy: 0.9793
# Epoch 18: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 500ms/step - loss: 0.0647 - accuracy: 0.9793 - val_loss: 1.8080 - val_accuracy: 0.6341
# Epoch 19/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0626 - accuracy: 0.9805
# Epoch 19: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 500ms/step - loss: 0.0626 - accuracy: 0.9805 - val_loss: 1.7538 - val_accuracy: 0.6499
# Epoch 20/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0534 - accuracy: 0.9820
# Epoch 20: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 500ms/step - loss: 0.0534 - accuracy: 0.9820 - val_loss: 1.9125 - val_accuracy: 0.6616
# Epoch 21/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9803
# Epoch 21: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 499ms/step - loss: 0.0631 - accuracy: 0.9803 - val_loss: 1.8824 - val_accuracy: 0.6470
# Epoch 22/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9829
# Epoch 22: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 500ms/step - loss: 0.0569 - accuracy: 0.9829 - val_loss: 1.7318 - val_accuracy: 0.6396
# Epoch 23/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0535 - accuracy: 0.9834
# Epoch 23: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 499ms/step - loss: 0.0535 - accuracy: 0.9834 - val_loss: 1.8195 - val_accuracy: 0.6566
# Epoch 24/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.9825
# Epoch 24: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 499ms/step - loss: 0.0561 - accuracy: 0.9825 - val_loss: 1.7436 - val_accuracy: 0.6442
# Epoch 25/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0497 - accuracy: 0.9841
# Epoch 25: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 499ms/step - loss: 0.0497 - accuracy: 0.9841 - val_loss: 1.7684 - val_accuracy: 0.6479
# Epoch 26/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0524 - accuracy: 0.9831
# Epoch 26: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 500ms/step - loss: 0.0524 - accuracy: 0.9831 - val_loss: 1.7144 - val_accuracy: 0.6506
# Epoch 27/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9853
# Epoch 27: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 501ms/step - loss: 0.0484 - accuracy: 0.9853 - val_loss: 2.0065 - val_accuracy: 0.6481
# Epoch 28/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0486 - accuracy: 0.9855
# Epoch 28: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 350s 498ms/step - loss: 0.0486 - accuracy: 0.9855 - val_loss: 2.0604 - val_accuracy: 0.6507
# Epoch 29/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0524 - accuracy: 0.9838
# Epoch 29: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 500ms/step - loss: 0.0524 - accuracy: 0.9838 - val_loss: 1.7194 - val_accuracy: 0.6355
# Epoch 30/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9865
# Epoch 30: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 500ms/step - loss: 0.0453 - accuracy: 0.9865 - val_loss: 1.9087 - val_accuracy: 0.6554
# Epoch 31/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9874
# Epoch 31: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 501ms/step - loss: 0.0418 - accuracy: 0.9874 - val_loss: 1.9029 - val_accuracy: 0.6458
# Epoch 32/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0476 - accuracy: 0.9863
# Epoch 32: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 499ms/step - loss: 0.0476 - accuracy: 0.9863 - val_loss: 1.8021 - val_accuracy: 0.6312
# Epoch 33/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9876
# Epoch 33: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 501ms/step - loss: 0.0393 - accuracy: 0.9876 - val_loss: 1.9616 - val_accuracy: 0.6543
# Epoch 34/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9872
# Epoch 34: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 500ms/step - loss: 0.0417 - accuracy: 0.9872 - val_loss: 1.8846 - val_accuracy: 0.6555
# Epoch 35/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9855
# Epoch 35: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 500ms/step - loss: 0.0487 - accuracy: 0.9855 - val_loss: 1.9653 - val_accuracy: 0.6451
# Epoch 36/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9880
# Epoch 36: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 500ms/step - loss: 0.0393 - accuracy: 0.9880 - val_loss: 1.9473 - val_accuracy: 0.6502
# Epoch 37/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9877
# Epoch 37: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 501ms/step - loss: 0.0406 - accuracy: 0.9877 - val_loss: 1.9232 - val_accuracy: 0.6534
# Epoch 38/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0344 - accuracy: 0.9897
# Epoch 38: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 501ms/step - loss: 0.0344 - accuracy: 0.9897 - val_loss: 1.9587 - val_accuracy: 0.6506
# Epoch 39/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9871
# Epoch 39: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 501ms/step - loss: 0.0428 - accuracy: 0.9871 - val_loss: 1.9847 - val_accuracy: 0.6449
# Epoch 40/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9884
# Epoch 40: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 499ms/step - loss: 0.0367 - accuracy: 0.9884 - val_loss: 2.0236 - val_accuracy: 0.6467
# Epoch 41/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9890
# Epoch 41: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 500ms/step - loss: 0.0371 - accuracy: 0.9890 - val_loss: 2.0538 - val_accuracy: 0.6577
# Epoch 42/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0388 - accuracy: 0.9883
# Epoch 42: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 500ms/step - loss: 0.0388 - accuracy: 0.9883 - val_loss: 1.8752 - val_accuracy: 0.6452
# Epoch 43/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0444 - accuracy: 0.9865
# Epoch 43: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 500ms/step - loss: 0.0444 - accuracy: 0.9865 - val_loss: 1.8262 - val_accuracy: 0.6337
# Epoch 44/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0384 - accuracy: 0.9896
# Epoch 44: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 500ms/step - loss: 0.0384 - accuracy: 0.9896 - val_loss: 1.8501 - val_accuracy: 0.6445
# Epoch 45/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9910
# Epoch 45: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 500ms/step - loss: 0.0301 - accuracy: 0.9910 - val_loss: 2.2227 - val_accuracy: 0.6151
# Epoch 46/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0457 - accuracy: 0.9868
# Epoch 46: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 501ms/step - loss: 0.0457 - accuracy: 0.9868 - val_loss: 2.0717 - val_accuracy: 0.6451
# Epoch 47/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0254 - accuracy: 0.9929
# Epoch 47: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 500ms/step - loss: 0.0254 - accuracy: 0.9929 - val_loss: 2.1899 - val_accuracy: 0.6426
# Epoch 48/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9888
# Epoch 48: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 500ms/step - loss: 0.0360 - accuracy: 0.9888 - val_loss: 2.2360 - val_accuracy: 0.6268
# Epoch 49/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9907
# Epoch 49: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 352s 501ms/step - loss: 0.0297 - accuracy: 0.9907 - val_loss: 1.9611 - val_accuracy: 0.6475
# Epoch 50/50
# 704/704 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9897
# Epoch 50: val_accuracy did not improve from 0.66264
# 704/704 [==============================] - 351s 500ms/step - loss: 0.0329 - accuracy: 0.9897 - val_loss: 2.0239 - val_accuracy: 0.6406

# %%
import os
import cv2
import numpy as np

# Assuming 'detect_and_crop_face' is a pre-defined function for face detection and cropping
def preprocess_and_predict_concatenated_model(model, dataframe):
    images = []
    labels = []

    # List of emotion labels corresponding to each model output
    emotion_labels = ['anger', 'contempt', 'disgust', 'sad', 'happy', 'fear', 'neutral', 'surprise']

    # Loop through each row of the dataframe
    for _, row in dataframe.iterrows():
        img_path = os.path.join('AffectNet', row['pth'])  # Adjust path if needed
        image = cv2.imread(img_path)

        # Apply face detection and cropping
        face = detect_and_crop_face(image)
        if face is not None:
            images.append(face.astype('float32') / 255.0)  # Normalize image to [0, 1]
            
            # Convert label to binary vector for each emotion
            labels.append([1 if row['label'] == emotion else 0 for emotion in emotion_labels])

    # Convert to numpy arrays
    images = np.array(images)
    labels = np.array(labels)

    # Predict using the concatenated model
    y_pred = model.predict(images)

    # Use argmax to find the index of the highest output for each prediction
    predicted_indices = np.argmax(y_pred, axis=-1)  # Get index of the highest value (emotion)

    # Map the predicted indices to emotion labels
    predicted_emotions = [emotion_labels[i] for i in predicted_indices]

    return labels, predicted_emotions  # Return both true labels and predicted emotions

# %%
# Get predictions
y_true, y_pred_classes = preprocess_and_predict_concatenated_model(model, val_df)
# Out:
# 177/177 [==============================] - 5s 22ms/step

# %%
# Convert true labels from binary vectors to emotion labels
emotion_labels = ['anger', 'contempt', 'disgust', 'sad', 'happy', 'fear', 'neutral', 'surprise']
y_true_labels = [' '.join([emotion_labels[i] for i, val in enumerate(row) if val == 1]) for row in y_true]

# Print classification report
print("Classification Report:")
print(classification_report(y_true_labels, y_pred_classes))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        anger       0.66      0.57      0.61       722
#     contempt       0.69      0.61      0.65       649
#      disgust       0.65      0.52      0.58       694
#         fear       0.58      0.73      0.65       609
#        happy       0.87      0.84      0.85       867
#      neutral       0.44      0.62      0.52       572
#          sad       0.57      0.53      0.55       599
#     surprise       0.64      0.65      0.65       923
#
#     accuracy                           0.64      5635
#    macro avg       0.64      0.63      0.63      5635
# weighted avg       0.65      0.64      0.64      5635

# %%
# Generate confusion matrix
cm = confusion_matrix(y_true_labels, y_pred_classes)

# Plot using seaborn
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=emotion_labels, yticklabels=emotion_labels)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
model.load_weights('AffectNet-Ensemble-Vision-v3.h5')

# %%
y_true, y_pred_classes = preprocess_and_predict_concatenated_model(model, val_df)
# Out:
# 177/177 [==============================] - 4s 20ms/step

# %%
# Convert true labels from binary vectors to emotion labels
emotion_labels = ['anger', 'contempt', 'disgust', 'sad', 'happy', 'fear', 'neutral', 'surprise']
y_true_labels = [' '.join([emotion_labels[i] for i, val in enumerate(row) if val == 1]) for row in y_true]

# Print classification report
print("Classification Report:")
print(classification_report(y_true_labels, y_pred_classes))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        anger       0.73      0.59      0.65       722
#     contempt       0.65      0.74      0.69       649
#      disgust       0.63      0.61      0.62       694
#         fear       0.64      0.67      0.65       609
#        happy       0.86      0.84      0.85       867
#      neutral       0.50      0.54      0.52       572
#          sad       0.50      0.68      0.58       599
#     surprise       0.76      0.60      0.67       923
#
#     accuracy                           0.66      5635
#    macro avg       0.66      0.66      0.65      5635
# weighted avg       0.68      0.66      0.66      5635

# %%
# Generate confusion matrix
cm = confusion_matrix(y_true_labels, y_pred_classes)

# Plot using seaborn
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=emotion_labels, yticklabels=emotion_labels)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
import matplotlib.pyplot as plt

# Define epochs based on history length
epochs = range(1, len(history.history['accuracy']) + 1)

# Plot Training vs Validation Accuracy
plt.figure(figsize=(6, 5))
plt.plot(epochs, history.history['accuracy'], 'bo-', label='Training Accuracy')
plt.plot(epochs, history.history['val_accuracy'], 'r*-', label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.show()

# Plot Training vs Validation Loss
plt.figure(figsize=(6, 5))
plt.plot(epochs, history.history['loss'], 'bo-', label='Training Loss')
plt.plot(epochs, history.history['val_loss'], 'r*-', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.show()
